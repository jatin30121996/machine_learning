# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
dirpath = "C:/Users/jatin/Pictures/Camera Roll" 
img = cv.imread(dirpath + "/first.png", cv.IMREAD_GRAYSCALE)

# %%
plt.imshow(img, cmap="gray")

# %%
img = cv.resize(img, (50, 50))
plt.imshow(img)

# %%
img.shape
# Out:
# (50, 50)

# %%
img = img[:40, :40]
plt.imshow(img)
